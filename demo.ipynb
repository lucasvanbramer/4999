# %%
from revision_pipeline import pipeline
from convokit import Corpus

# %%
def get_corpus_leaf_ids(c: Corpus) -> set:
    leaves = set()
    not_leaves = set()
    for utt in c.iter_utterances():
        if utt.id not in not_leaves:
            leaves.add(utt.id)
        if utt.reply_to in leaves:
            leaves.remove(utt.reply_to)
        not_leaves.add(utt.reply_to)
    return leaves


def print_corpus(c: Corpus) -> None:
    leaves = get_corpus_leaf_ids(c)

    for leaf_id in leaves:
        utt = c.get_utterance(leaf_id)
        chain = [utt]
        while utt.reply_to:
            utt = c.get_utterance(utt.reply_to)
            chain.append(utt)

        depth = ""
        print("this conversation is", len(chain), "utterances long.")
        for utterance in reversed(chain):
            print(depth + utterance.text.replace("\n", " "))
            depth += "--> "
        print("\n")

# %%
corp = pipeline.get_corpus("Cornell_University", write_intermediate_to_disk=True)
# print_corpus(c)
# Out:
# updating intermediate at ./intermediate_format/Cornell_University.json
# intermediate already up to date
# generating corpus...
# this is the u_text: :::Cornell is a private as well as a federal land-grant univ
# these are the block hashes: da23dac8 da23dac8
# this is the u_text: |action2=PR
# |action2date=21:28, 22 May 2006
# these are the block hashes: 9f468734 b6a792be
# this is the u_text: ::::::::Enough. You've both made your points now move on. [[
# these are the block hashes: 6481b9ad
# this is the u_text: </blockquote>
# </blockquote>
# {{reflist}}
# ::Thanks, Tydtsgch34
# these are the block hashes: 4f9260a8 4f9260a8 4f4ff790 75ef1cff 793c3fa8 4d8d7199 0a94b27b 298eeb80 1c601ca1 a0048fba 7b7948cb ced11a5e
# this is the u_text: == External links modified ==
# == External links modified ==
#
# these are the block hashes: dba70bb0 dba70bb0 ec6b0845 77f8d2ee 2cb53027 e0ac3e80 e08540ea 2cb53027 620dc57e 91e242f3 eb14d894 2edc8760
# this is the u_text: {{WikiProject Universities|class=B|importance=high}}
# {{WikiP
# these are the block hashes: 1dae66f4 1dae66f4
# this is the u_text: :[[WP:UNDUE]] applies to viewpoints, not information. --[[Us
# these are the block hashes: f1040c77
# this is the u_text: == External links modified ==
# == External links modified ==
#
# these are the block hashes: dba70bb0 dba70bb0 ec6b0845
# this is the u_text: I have just modified {{plural:1|one external link|1 external
# these are the block hashes: b5fc8455 40cab707
# this is the u_text: |action6=GAN
# |action6=GAN
# |action6date=17:20, 21 September 2
# these are the block hashes: 691cee4f 691cee4f fe67e315 f931d963 2e5f35d7 9d0dea67 34460fd9 df876ff9 c3611c68 75c42672 fe4c11d0
# this is the u_text: <blockquote>
# <blockquote>
# these are the block hashes: 4b611991 4b611991
# this is the u_text: {{WikiProject Qatar|class=B|importance=low}}
# these are the block hashes: 3543cc3c
# this is the u_text: {{OnThisDay|date1=2008-10-07|oldid1=243341341|date2=2011-10-
# these are the block hashes: c9923b6a c9923b6a
# this is the u_text: {{ArticleHistory
# {{ArticleHistory
# |action1=PR
# |action1date=0
# these are the block hashes: a37d8f17 a37d8f17 9eac91e9 5ab60a18
# this is the u_text: :::: This game of parroting rankings to the point of [[WP:UN
# these are the block hashes: 955638df
# this is the u_text: :::First, there are many short sentences in many Wiki articl
# these are the block hashes: 0463bba2 f4d8c460
# this is the u_text: :::::::Good grief! ''"Yawn"???'' Talk about "personal attack
# these are the block hashes: 391409f7
# this is the u_text: |topic=Education
# |topic=Education
# these are the block hashes: 0caf16c8 0caf16c8
# this is the u_text: "Cornell is the federal land-grant institution of New York S
# these are the block hashes: e90752ef
# this is the u_text: These are examples of [[Wikipedia:Avoid_academic_boosterism|
# these are the block hashes: e147fa08 2f11868b e6496b9d 8f403b90 a4abd474
# this is the u_text: Cornell has an endowment of over $5 billion.<ref>{{cite web|
# these are the block hashes: 38f1dfab 38f1dfab
# this is the u_text: {{WikiProject New York|class=B|importance=Low|Cornell=yes|Co
# these are the block hashes: 4067119b 4067119b
# this is the u_text: Disagree with merging. We don't want to have all the details
# these are the block hashes: c2dff175
# this is the u_text: :Thanks for thinking through that detailed list Eustress. Ve
# these are the block hashes: 6886313f
# this is the u_text: {{WikiProjectBannerShell|collapsed=yes |1=
# {{WikiProjectBann
# these are the block hashes: bf636c8f bf636c8f
# this is the u_text: :::::Your view is classic POV. Rankings are a matter of publ
# these are the block hashes: 93a2f080
# this is the u_text: :::::: Yawn, personal attacks, what a surprise. For the reco
# these are the block hashes: a91a5b9e
# this is the u_text: |action2link=Wikipedia:Peer review/Cornell University/archiv
# these are the block hashes: 6cf57523
# this is the u_text: </blockquote>
# </blockquote>
# {{reflist}}
# these are the block hashes: 4f9260a8 4f9260a8 4f4ff790
# this is the u_text: |action2result=reviewed
# |action2oldid=54592855
# |action3=PR
# |
# these are the block hashes: a09ddfe7 5bff352d 42af57dd 23e584ac
# this is the u_text: |action3link=Wikipedia:Peer review/Cornell University/archiv
# these are the block hashes: f523f2a4
# this is the u_text: </blockquote>
# </blockquote>
# {{reflist}}
# ::Thanks, Tydtsgch34
# these are the block hashes: 4f9260a8 4f9260a8 4f4ff790 75ef1cff 793c3fa8 4d8d7199 0a94b27b 298eeb80 1c601ca1 a0048fba 7b7948cb c0360d43
# this is the u_text: |action1link=Wikipedia:Peer review/Cornell University/archiv
# these are the block hashes: f8f521ac
# this is the u_text: == Seal ==
# == Seal ==
# [[User talk:Ilberia]] continually puts
# these are the block hashes: 2d76df41 2d76df41 6ace08f2
# this is the u_text: {{Talk header}}
# {{Talk header}}
# these are the block hashes: 9529ef46 9529ef46
# this is the u_text: == Help ==
# == Help ==
# I am a student at Cornell University c
# these are the block hashes: d3f42334 d3f42334 e3c22da9
# this is the u_text: Cheers.—[[User:Cyberbot II|<sup style="color:green;font-fami
# these are the block hashes: 476a0e08
# this is the u_text: ::The sentences don't really add much value to the encyclope
# these are the block hashes: a7fe1529
# this is the u_text: ::Are you posting under more than one account? =//= [[User:J
# these are the block hashes: adc2ff36
# this is the u_text: ==Template of faculty==
# ==Template of faculty==
# Well, i trie
# these are the block hashes: 47af0925 47af0925 90760575
# this is the u_text: |action5=FAR
# |action5=FAR
# |action5date=14:40, 5 December 200
# these are the block hashes: 4ac0eaea 4ac0eaea 356dbc6a 5992ff22 33e800bc a3fa3b25
# this is the u_text: == External links modified ==
# == External links modified ==
#
# these are the block hashes: dba70bb0 dba70bb0 ec6b0845 1d328626 1c85287c 7709b793 91e242f3 eb14d894 e92065c6
# this is the u_text: I have just added archive links to {{plural:2|one external l
# these are the block hashes: cac87ac7 814e1fad 833996a4 d97cd1df
# this is the u_text: When you have finished reviewing my changes, please set the
# these are the block hashes: bdb4fa2f a2cf3a26
# this is the u_text: {{WP1.0|WPCD=y}}
# {{WP1.0|WPCD=y}}
# these are the block hashes: 57a4fc06 57a4fc06
# this is the u_text: == Copyright problem removed ==
# == Copyright problem removed
# these are the block hashes: b4538cc0 b4538cc0 8c2dab95
# this is the u_text: ::Hi Jeff. For a high-level discussion on this, I've initiat
# these are the block hashes: 02befca3 a19e9b8a
# this is the u_text: ==Admissions selectivity==
# ==Admissions selectivity==
# I remo
# these are the block hashes: 852c9111 852c9111 895e9667
# this is the u_text: == Does John Cleese truly represent "Famous current and form
# these are the block hashes: 49e1966c 49e1966c 828f1ce9
# this is the u_text: I have again reverted drastic edits to this article, which w
# these are the block hashes: 007506fc 007506fc 2f754978 6ad2b4d7 d8231591 635c4f63 1f8eb61a 318456a7 a801146f ae4a8523
# this is the u_text: == Proposal to merge [[Cornell gorge suicides]] with the Cor
# these are the block hashes: ffac7c3d ffac7c3d
# this is the u_text: ::Hi Jeff. For a high-level discussion on this, I've initiat
# these are the block hashes: 02befca3
# this is the u_text: == External links modified ==
# == External links modified ==
#
# these are the block hashes: dba70bb0 dba70bb0 ec6b0845 89f0249e af4f217c bbcd27a5 1c85287c be274207 232e0ff6 7ff59dd2 f65041e6 91e242f3 eb14d894 78733fd0
# this is the u_text: ::::Following up on our discussion over [[User talk:JohnInDC
# these are the block hashes: e33b8ac7
# this is the u_text: {{ArticleHistory
# {{ArticleHistory
# these are the block hashes: a37d8f17 a37d8f17
# this is the u_text: == External links modified ==
# == External links modified ==
#
# these are the block hashes: dba70bb0 dba70bb0 ec6b0845 6fc85b96 12ba9cb7 1c85287c c11ca07d 135a7cd4 36703f8a 67463662 42d5f115 0296101e 3df8a82a db8406df dd045f92 277a5980 56fbc0ff bdb8c423 6dd886f4 6766d87a 9b45a98f 36737754 a9a6e965 811a0738 75ad38d4 a9f0ed2e 183309b5 1ca5f7ec b874fd06 354cf077 9bedb478 7e296442 5909ae74 918abe1a 635e2ee2 cecabfc1 2814b010 807d1138 06107f67 30204d02 91e242f3 eb14d894 74d0e250
# this is the u_text: == Largest indoor natural rock climbing wall in North Americ
# these are the block hashes: 78174bb4 78174bb4 02ae22da
# this is the u_text: </blockquote>
# </blockquote>
# {{reflist}}
# ::Thanks, Tydtsgch34
# these are the block hashes: 4f9260a8 4f9260a8 4f4ff790 75ef1cff 793c3fa8 4d8d7199 0a94b27b 298eeb80 1c601ca1 a0048fba 7b7948cb
# this is the u_text: ==Environmental Record text==
# ==Environmental Record text==
#
# these are the block hashes: 94446f34 94446f34 e77a8cef
# this is the u_text: == <s>Boosterism</s> removal ==
# == <s>Boosterism</s> removal
# these are the block hashes: da95a3f4 da95a3f4
# this is the u_text: == External links modified ==
# == External links modified ==
#
# these are the block hashes: dba70bb0 dba70bb0 ec6b0845 a9fa4c1e ebabe486 91e242f3 eb14d894 3f13196c
# this is the u_text: <!--Template:Undated--> <!--Autosigned by SineBot-->
# <!--Tem
# these are the block hashes: 8a921afb 8a921afb 6a960db0
# this is the u_text: :If those statements are supported by sources or are summari
# these are the block hashes: 880eb03b 880eb03b
# this is the u_text: {{sourcecheck|checked=false}}
# these are the block hashes: a2cf3a26
# this is the u_text: I have just added archive links to {{plural:4|one external l
# these are the block hashes: 688e27fe e727b191 0114366f 8a8f91a1 2876aa16 d97cd1df
# this is the u_text: }}
# }}
# these are the block hashes: 67c0904e 67c0904e
# this is the u_text: :::Instead of deleting the work of contributors, Eustress sh
# these are the block hashes: 491b97ce 491b97ce 8b4d9513
# this is the u_text: |action1oldid=43238831
# these are the block hashes: ed3d34aa
# this is the u_text: :I think you're taking this a little far. The comments are n
# these are the block hashes: 5c24bf87 30083735
# this is the u_text: Cheers.—[[User:Cyberbot II|<sup style="color:green;font-fami
# these are the block hashes: cb5f3be4
# this is the u_text: ::Not quite.  The publishing of information in an encycloped
# these are the block hashes: 6241a2f0 e74672e5 074dff2e
# this is the u_text: Cheers.—[[User:Cyberbot II|<sup style="color:green;font-fami
# these are the block hashes: 0657fe2e
# this is the u_text: |action8=GAN
# |action8=GAN
# |action8date=01:50, 15 December 20
# these are the block hashes: b1153e18 b1153e18 866ed049 19ac65d8 257c95da 1250df9c
# this is the u_text: == External links modified ==
# == External links modified ==
#
# these are the block hashes: dba70bb0 dba70bb0 ec6b0845 3800bc75 7ac48983 f43a8e11 1338eef0 bdb4fa2f a2cf3a26 c6657018
# this is the u_text: == Assertion that Cornell is a " is an American private Ivy
# these are the block hashes: 888f127f 888f127f 11948c45
# this is the u_text: ::Not quite.  The publishing of information in an encycloped
# these are the block hashes: 6241a2f0 e74672e5 074dff2e df7a0cfe
# this is the u_text: :::::: Why don't you just offer a suggested edit to Tydtsgch
# these are the block hashes: 802885a9
# this is the u_text: ::Cornell identifies itself as a private AND public universi
# these are the block hashes: 06e627b3
# this is the u_text: :::Instead of deleting the work of contributors, Eustress sh
# these are the block hashes: 491b97ce 491b97ce
# this is the u_text: :This is a factual statement.
# <blockquote>''Many of Cornell'
# these are the block hashes: 0e154a1b fd7cd134 262cc6cd
# this is the u_text: :::That is an unwarranted personal attack. [[User:Drmies|Drm
# these are the block hashes: 5c3530e6 b9428b36
# this is the u_text: |action1result=reviewed
# these are the block hashes: 70b7cf6b
# corpus generated.
