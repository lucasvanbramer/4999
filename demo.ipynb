# %%
from revision_pipeline import pipeline
from convokit import Corpus

# %%
def get_corpus_leaf_ids(c: Corpus) -> set:
    leaves = set()
    not_leaves = set()
    for utt in c.iter_utterances():
        if utt.id not in not_leaves:
            leaves.add(utt.id)
        if utt.reply_to in leaves:
            leaves.remove(utt.reply_to)
        not_leaves.add(utt.reply_to)
    return leaves


def print_corpus(c: Corpus) -> None:
    leaves = get_corpus_leaf_ids(c)

    for leaf_id in leaves:
        utt = c.get_utterance(leaf_id)
        chain = [utt]
        while utt.reply_to:
            utt = c.get_utterance(utt.reply_to)
            chain.append(utt)

        depth = ""
        print("this conversation is", len(chain), "utterances long.")
        for utterance in reversed(chain):
            print(depth + utterance.text.replace("\n", " ")[:80])
            depth += "--> "
        print("\n")

# %%
corp = pipeline.get_corpus("Cornell_University", write_intermediate_to_disk=True)
print_corpus(corp)
# Out:
# updating intermediate at ./intermediate_format/Cornell_University.json
# intermediate already up to date
# generating corpus...
# corpus generated.
# this conversation is 1 utterances long.
# |topic=Education
#
#
# this conversation is 1 utterances long.
# |action8=GAN |action8date=01:50, 15 December 2010 |action8link=Talk:Cornell Univ
#
#
# this conversation is 1 utterances long.
# == Seal == [[User talk:Ilberia]] continually puts his or her altered image of th
#
#
# this conversation is 2 utterances long.
# == External links modified == Hello fellow Wikipedians, I have just modified 5 e
# --> I have just modified {{plural:1|one external link|1 external links}} on [[Cornel
#
#
# this conversation is 3 utterances long.
# I have again reverted drastic edits to this article, which were implemented with
# --> :Thanks for thinking through that detailed list Eustress. Very helpful! I'm not
# --> --> ::Hi Jeff. For a high-level discussion on this, I've initiated a thread at [[Wik
#
#
# this conversation is 8 utterances long.
# {{ArticleHistory |action1=PR |action1date=03:15, 11 March 2006
# --> |action1link=Wikipedia:Peer review/Cornell University/archive1
# --> --> |action1result=reviewed
# --> --> --> |action1oldid=43238831
# --> --> --> --> |action2=PR |action2date=21:28, 22 May 2006
# --> --> --> --> --> |action2link=Wikipedia:Peer review/Cornell University/archive2
# --> --> --> --> --> --> |action2result=reviewed |action2oldid=54592855 |action3=PR |action3date=20:56, 1
# --> --> --> --> --> --> --> |action3link=Wikipedia:Peer review/Cornell University/archive3
#
#
# this conversation is 2 utterances long.
# == External links modified == Hello fellow Wikipedians, I have just modified 5 e
# --> I have just added archive links to {{plural:2|one external link|2 external links
#
#
# this conversation is 2 utterances long.
# == Proposal to merge [[Cornell gorge suicides]] with the Cornell Univ article ==
# --> Disagree with merging. We don't want to have all the details about the history o
#
#
# this conversation is 1 utterances long.
# :::Cornell is a private as well as a federal land-grant university. The article
#
#
# this conversation is 2 utterances long.
# {{sourcecheck|checked=false}}
# --> Cheers.—[[User:Cyberbot II|<sup style="color:green;font-family:Courier">cyberbot
#
#
# this conversation is 1 utterances long.
# ==Template of faculty== Well, i tried, but i dont have a cropping tool that work
#
#
# this conversation is 1 utterances long.
# |action6=GAN |action6date=17:20, 21 September 2010 |action6link=Talk:Cornell Uni
#
#
# this conversation is 1 utterances long.
# Cornell has an endowment of over $5 billion.<ref>{{cite web|last=Doolittle|first
#
#
# this conversation is 2 utterances long.
# </blockquote> {{reflist}} ::Thanks, Tydtsgch34. Allow me to comment on the conte
# --> :::::: Why don't you just offer a suggested edit to Tydtsgch34's contribution an
#
#
# this conversation is 2 utterances long.
# {{sourcecheck|checked=false}}
# --> Cheers.—[[User:Cyberbot II|<sup style="color:green;font-family:Courier">cyberbot
#
#
# this conversation is 3 utterances long.
# :If those statements are supported by sources or are summaries of slightly longe
# --> ::Are you posting under more than one account? =//= [[User:Johnny Squeaky|Johnny
# --> --> :::That is an unwarranted personal attack. [[User:Drmies|Drmies]] ([[User talk:D
#
#
# this conversation is 1 utterances long.
# {{WikiProject Universities|class=B|importance=high}}
#
#
# this conversation is 1 utterances long.
# == Does John Cleese truly represent "Famous current and former Cornell faculty"?
#
#
# this conversation is 1 utterances long.
# == Help == I am a student at Cornell University currently working on developing
#
#
# this conversation is 2 utterances long.
# == External links modified == Hello fellow Wikipedians, I have just modified 5 e
# --> I have just added archive links to {{plural:4|one external link|4 external links
#
#
# this conversation is 4 utterances long.
# ==Environmental Record text== I recently undid an expansion of information about
# --> :[[WP:UNDUE]] applies to viewpoints, not information. --[[User:The Cunctator|The
# --> --> ::Not quite.  The publishing of information in an encyclopedia article itself is
# --> --> --> ::::Following up on our discussion over [[User talk:JohnInDC|here]], we did atte
#
#
# this conversation is 3 utterances long.
# == Assertion that Cornell is a " is an American private Ivy League research univ
# --> "Cornell is the federal land-grant institution of New York State, a private endo
# --> --> ::Cornell identifies itself as a private AND public university. See "Identity" s
#
#
# this conversation is 1 utterances long.
# == Copyright problem removed == Prior content in this article duplicated one or
#
#
# this conversation is 1 utterances long.
# <blockquote>
#
#
# this conversation is 1 utterances long.
# {{Talk header}}
#
#
# this conversation is 1 utterances long.
# {{WP1.0|WPCD=y}}
#
#
# this conversation is 1 utterances long.
# == Largest indoor natural rock climbing wall in North America == I find it highl
#
#
# this conversation is 3 utterances long.
# == <s>Boosterism</s> removal ==
# --> These are examples of [[Wikipedia:Avoid_academic_boosterism|academic boosterism]
# --> --> :I think you're taking this a little far. The comments are no different than on
#
#
# this conversation is 1 utterances long.
# |action5=FAR |action5date=14:40, 5 December 2008 |action5link=Wikipedia:Featured
#
#
# this conversation is 2 utterances long.
# When you have finished reviewing my changes, please set the ''checked'' paramete
# --> Cheers.—[[User:Cyberbot II|<sup style="color:green;font-family:Courier">cyberbot
#
#
# this conversation is 1 utterances long.
# :::Instead of deleting the work of contributors, Eustress should have productive
#
#
# this conversation is 1 utterances long.
# ==Admissions selectivity== I removed the following statement from the article: "
#
#
# this conversation is 1 utterances long.
# {{OnThisDay|date1=2008-10-07|oldid1=243341341|date2=2011-10-07|oldid2=454426194|
#
#
# this conversation is 1 utterances long.
# }}
#
#
# this conversation is 1 utterances long.
# <!--Template:Undated--> <!--Autosigned by SineBot--> :::One caption saying publi
#
#
# this conversation is 10 utterances long.
# == <s>Boosterism</s> removal ==
# --> These are examples of [[Wikipedia:Avoid_academic_boosterism|academic boosterism]
# --> --> :This is a factual statement. <blockquote>''Many of Cornell's schools have been
# --> --> --> ::The sentences don't really add much value to the encyclopedia, and [[Wikipedia
# --> --> --> --> :::First, there are many short sentences in many Wiki articles that "really don'
# --> --> --> --> --> :::: This game of parroting rankings to the point of [[WP:UNDUE|undue influence]
# --> --> --> --> --> --> :::::Your view is classic POV. Rankings are a matter of public record just like
# --> --> --> --> --> --> --> :::::: Yawn, personal attacks, what a surprise. For the record, I went to MIT wh
# --> --> --> --> --> --> --> --> :::::::Good grief! ''"Yawn"???'' Talk about "personal attacks". Apparently you a
# --> --> --> --> --> --> --> --> --> ::::::::Enough. You've both made your points now move on. [[User:ElKevbo|ElKevbo
#
#
# this conversation is 1 utterances long.
# {{WikiProject New York|class=B|importance=Low|Cornell=yes|Cornell-importance=top
#
#
# this conversation is 2 utterances long.
# {{WikiProjectBannerShell|collapsed=yes |1=
# --> {{WikiProject Qatar|class=B|importance=low}}
